# %% [markdown]
# <a href="https://colab.research.google.com/github/WatchTheory/e_vehicle_poplation_data/blob/main/Electric_Vehicle_Population_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import sheets # importing from google

import numpy as np
import pandas as pd   # importing pandas libraries

# %%
sheet_url = "https://docs.google.com/spreadsheets/d/1RLvIYGFAMQ_vN2uJUdfiwnRdDN-K5-IrqGQgvyjxvE4/edit?gid=157591865#gid=157591865"
sheet = sheets.InteractiveSheet(url=sheet_url)            # Create interactive shees with url

# %%
# Convert the sheet data to a Pandas DataFrame
ev_data = sheet.as_df()

# %%
ev_data.head()
# Out:
#    VIN (1-10)     County          City State Postal Code Model Year    Make  \
# 0  5YJ3E1EB5K     Yakima        Yakima    WA       98901       2019   TESLA
# 1  1C4RJXU67R     Kitsap  Port Orchard    WA       98367       2024    JEEP
# 2  KNDCD3LD0N  Snohomish      Lynnwood    WA       98036       2022     KIA
# 3  5UXKT0C37H       King        Auburn    WA       98001       2017     BMW
# 4  1N4AZ0CP1D     Skagit  Mount Vernon    WA       98273       2013  NISSAN
#
#       Model                   Electric Vehicle Type  \
# 0   MODEL 3          Battery Electric Vehicle (BEV)
# 1  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 2      NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 3        X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 4      LEAF          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility Electric Range Base MSRP  \
# 0           Clean Alternative Fuel Vehicle Eligible            220         0
# ...
